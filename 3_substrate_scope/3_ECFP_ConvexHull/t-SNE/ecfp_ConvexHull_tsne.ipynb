# %%
import platform
platform.platform()
# Out:
# 'macOS-15.6.1-arm64-arm-64bit'

# %%
import sys
sys.version
# Out:
# '3.10.19 | packaged by conda-forge | (main, Oct 22 2025, 22:46:49) [Clang 19.1.7 ]'

# %%
import os
sys.path.append(os.path.abspath("../../.."))

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.8'

# %%
import matplotlib.pyplot as plt
from matplotlib import patches

# %%
import numpy as np
np.__version__
# Out:
# '1.23.5'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
import scipy
scipy.__version__
# Out:
# '1.15.3'

# %%
from SSMetrics import metrics

# %%
df1 = pd.read_csv("../../../1_dataset/4_ECFP/2_t-SNE/ecfp_tsne.csv")
df1.shape
# Out:
# (4665, 9)

# %%
df1.columns
# Out:
# Index(['InChI', 'K3FeCN6', 'MesAcr+BF4-', 'CuCl', 'Diacetyl', 'T(p-OMe)PPCo',
#        'Electrode', 'tSNE1', 'tSNE2'],
#       dtype='object')

# %%
conditions = [["K3FeCN6",[(255/255, 75/255, 0/255)], "K$_3$[Fe(CN)$_6$]"],
              ["MesAcr+BF4-", [(153/255, 0/255, 153/255)], "MesAcr$^+$BF$_4^-$"],
              ["CuCl", [(3/255, 175/255, 122/255)], "CuCl"],
              ["Diacetyl", [(246/255, 170/255, 0/255)], "Diacetyl"],
              ["T(p-OMe)PPCo", [(77/255, 196/255, 255/255)], "T($p$-OMe)PPCo"],
              ["Electrode", [(255/255, 128/255, 130/255)], "Electrode"]]

# %%
li_numbers = []
li_convexhull = []

# %%
for i in range(6):
    condition = conditions[i][0]
    colour = conditions[i][1]
    title = conditions[i][2]

    print(df1[condition].value_counts())

    x_p = df1[df1[condition] == 1].tSNE1
    y_p = df1[df1[condition] == 1].tSNE2

    x_n = df1[df1[condition] == -1].tSNE1
    y_n = df1[df1[condition] == -1].tSNE2

    x_u = df1[df1[condition] == 0].tSNE1
    y_u = df1[df1[condition] == 0].tSNE2

    df2 = df1[df1[condition] == 1].loc[:, "tSNE1":"tSNE2"]
    li_numbers.append(len(df2))

    array2 = df2.to_numpy()

    area, vertices = metrics.metrics_ConvexHull(array2)
    li_convexhull.append(area)

    print(f"\nArea: {area}")

    fig = plt.figure()
    ax = fig.add_subplot()

    polygon = patches.Polygon(array2[vertices], closed=True, label="ConvexHull",
                              color=colour[0], alpha=0.2)

    if len(x_n) != 0:
        p1 = ax.scatter(x_u, y_u, label="Unlabeled",
                        s=2, c=[(132/255, 145/255, 158/255)], marker=".", alpha=0.3)
        p2 = ax.add_patch(polygon)
        p3 = ax.scatter(x_n, y_n, label="Negative",
                        s=20, c=[(0/255, 90/255, 255/255)], marker="o",
                        edgecolors="k", linewidths=0.2)
        p4 = ax.scatter(x_p, y_p, label="Positive",
                        s=20, c=colour, marker="o",
                        edgecolors="k", linewidths=0.2)

        handles = [p4, p3, p1, p2]
        labels = [p4.get_label(), p3.get_label(), p1.get_label(), p2.get_label()]
        
    else:
        p1 = ax.scatter(x_u, y_u, label="Unlabeled",
                        s=2, c=[(132/255, 145/255, 158/255)], marker=".", alpha=0.3)
        p2 = ax.add_patch(polygon)
        p4 = ax.scatter(x_p, y_p, label="Positive",
                        s=20, c=colour, marker="o",
                        edgecolors="k", linewidths=0.2)

        handles = [p4, p1, p2]
        labels = [p4.get_label(), p1.get_label(), p2.get_label()]

    ax.legend(handles, labels, loc="upper right", fontsize=10)

    ax.set_xlabel("t-SNE 1", fontsize=15)
    ax.set_ylabel("t-SNE 2", fontsize=15)
    ax.set_title(title, fontsize=20)

    plt.savefig(f"{condition}.png", dpi=300)
    plt.show()
# Out:
# K3FeCN6
#  0    4591
# -1      51
#  1      23
# Name: count, dtype: int64
#
# Area: 205.35741475033825
# MesAcr+BF4-
# 0    4645
# 1      20
# Name: count, dtype: int64
#
# Area: 142.70999102211798
# CuCl
# 0    4646
# 1      19
# Name: count, dtype: int64
#
# Area: 20.902419861430484
# Diacetyl
# 0    4653
# 1      12
# Name: count, dtype: int64
#
# Area: 44.108481388792924
# T(p-OMe)PPCo
# 0    4656
# 1       9
# Name: count, dtype: int64
#
# Area: 141.15694790116217
# Electrode
# 0    4656
# 1       9
# Name: count, dtype: int64
#
# Area: 121.44655198835596

# %%
labels = []

for i in range(6):
    labels.append(f"{conditions[i][2]} ({li_numbers[i]})")
    
labels
# Out:
# ['K$_3$[Fe(CN)$_6$] (23)',
#  'MesAcr$^+$BF$_4^-$ (20)',
#  'CuCl (19)',
#  'Diacetyl (12)',
#  'T($p$-OMe)PPCo (9)',
#  'Electrode (9)']

# %%
conditions.append(["AllPhenols"])

df2 = df1.loc[:, "tSNE1":"tSNE2"]
li_numbers.append(len(df2))

array2 = df2.to_numpy()

area, _ = metrics.metrics_ConvexHull(array2)
li_convexhull.append(area)

print(f"\nArea: {area}")
# Out:
# Area: 472.2405619812289

# %%
df_result = pd.DataFrame({"Condition": [e[0] for e in conditions],
                          "Number":li_numbers,
                          "Area": li_convexhull})
df_result
# Out:
#       Condition  Number        Area
# 0       K3FeCN6      23  205.357415
# 1   MesAcr+BF4-      20  142.709991
# 2          CuCl      19   20.902420
# 3      Diacetyl      12   44.108481
# 4  T(p-OMe)PPCo       9  141.156948
# 5     Electrode       9  121.446552
# 6    AllPhenols    4665  472.240562

# %%
df_result.to_csv("ecfp_ConvexHull_tsne.csv", index=False)
