# %%
import platform
platform.platform()
# Out:
# 'macOS-15.6.1-arm64-arm-64bit'

# %%
import sys
sys.version
# Out:
# '3.10.19 | packaged by conda-forge | (main, Oct 22 2025, 22:46:49) [Clang 19.1.7 ]'

# %%
import os
sys.path.append(os.path.abspath("../.."))

# %%
import numpy as np
np.__version__
# Out:
# '1.23.5'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.3.0'

# %%
from SSMetrics import loo_std_knn

# %%
df1 = pd.read_csv("../../1_dataset/2_Mordred/mordred.csv")
df1.shape
# Out:
# (74, 1336)

# %%
df1.columns
# Out:
# Index(['SMILES', 'InChI', 'InChIKey', 'K3FeCN6', 'ABC', 'ABCGG', 'nAcid',
#        'nBase', 'SpAbs_A', 'SpMax_A',
#        ...
#        'SRW10', 'TSRW10', 'MW', 'AMW', 'WPath', 'WPol', 'Zagreb1', 'Zagreb2',
#        'mZagreb1', 'mZagreb2'],
#       dtype='object', length=1336)

# %%
df1["K3FeCN6"].value_counts()
# Out:
# K3FeCN6
# -1    51
#  1    23
# Name: count, dtype: int64

# %%
df2 = df1.iloc[:, 4:]
df2.shape
# Out:
# (74, 1332)

# %%
df2.columns
# Out:
# Index(['ABC', 'ABCGG', 'nAcid', 'nBase', 'SpAbs_A', 'SpMax_A', 'SpDiam_A',
#        'SpAD_A', 'SpMAD_A', 'LogEE_A',
#        ...
#        'SRW10', 'TSRW10', 'MW', 'AMW', 'WPath', 'WPol', 'Zagreb1', 'Zagreb2',
#        'mZagreb1', 'mZagreb2'],
#       dtype='object', length=1332)

# %%
x = np.array(df2)
x.shape
# Out:
# (74, 1332)

# %%
y = np.array(df1["K3FeCN6"])
y.shape
# Out:
# (74,)

# %%
accuracy = []
precision = []
recall = []
f1 = []

for i in range(1, 16):
    classifier = loo_std_knn(x, y, i)

    accuracy.append(classifier[2])
    precision.append(classifier[3])
    recall.append(classifier[4])
    f1.append(classifier[5])
    
df_knn = pd.DataFrame({"k": list(range(1, 16)),
                       "Accuracy": accuracy,
                       "Precision": precision,
                       "Recall": recall,
                       "F1": f1})
df_knn
# Out:
#      k  Accuracy  Precision    Recall        F1
# 0    1  0.756757   0.586207  0.739130  0.653846
# 1    2  0.743243   0.642857  0.391304  0.486486
# 2    3  0.783784   0.629630  0.739130  0.680000
# 3    4  0.716216   0.550000  0.478261  0.511628
# 4    5  0.743243   0.583333  0.608696  0.595745
# 5    6  0.729730   0.588235  0.434783  0.500000
# 6    7  0.743243   0.600000  0.521739  0.558140
# 7    8  0.743243   0.611111  0.478261  0.536585
# 8    9  0.729730   0.565217  0.565217  0.565217
# 9   10  0.729730   0.578947  0.478261  0.523810
# 10  11  0.729730   0.571429  0.521739  0.545455
# 11  12  0.729730   0.588235  0.434783  0.500000
# 12  13  0.716216   0.550000  0.478261  0.511628
# 13  14  0.702703   0.529412  0.391304  0.450000
# 14  15  0.729730   0.571429  0.521739  0.545455

# %%
df_knn.to_csv("knn_mordred.csv", index=False)
